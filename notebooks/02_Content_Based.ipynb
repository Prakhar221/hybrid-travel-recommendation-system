# %% [markdown]
# # 02. Content-Based Recommendation
#
# Uses TF-IDF Vectorization and Cosine Similarity to find similar places.

# %%
import sys
from pathlib import Path
ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT_DIR))

from src.preprocessing import DataPreprocessor
from src.content_based import ContentBasedRecommender

preproc = DataPreprocessor()
bus_df = preproc.load_businesses()

cb_recommender = ContentBasedRecommender()
cb_recommender.fit(bus_df)

recs = cb_recommender.recommend('Los Agaves', top_k=5)
recs
