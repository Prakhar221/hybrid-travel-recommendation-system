# %% [markdown]
# # 04. Model Evaluation & Benchmark Suite
#
# This notebook runs empirical model evaluation following the strict **>=5 interaction protocol** per user.
#
# ### Evaluation Rules:
# 1. **User Eligibility**: Users with >= 5 interactions are eligible for test holdout.
# 2. **User-Wise Split**: 20% held-out test set per eligible user.
# 3. **Candidate Exclusion**: Already-seen training items are strictly excluded from recommendation candidates.
# 4. **Relevant Item Threshold**: Ratings >= 4.0 in test set.
# 5. **Sample Disclaimer**: Results on small demo samples are pipeline-validation benchmarks.

# %%
import sys
from pathlib import Path
ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT_DIR))

from src.evaluation import run_full_dataset_evaluation

# Run evaluation (automatically detects raw Yelp CSVs if present in data/raw/)
stats, benchmark_df = run_full_dataset_evaluation(min_interactions=5)

print("STATUTORY AUDIT PARAMETERS:")
for k, v in stats.items():
    print(f"  {k}: {v}")

print("\nLIVE BENCHMARK METRICS:")
benchmark_df
