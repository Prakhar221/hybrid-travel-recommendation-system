# %% [markdown]
# # 01. Exploratory Data Analysis (EDA)
#
# This notebook analyzes the real Yelp business and user interaction dataset sample.

# %%
import sys
from pathlib import Path
ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT_DIR))

import pandas as pd
import numpy as np
from src.preprocessing import DataPreprocessor

preproc = DataPreprocessor()
bus_df = preproc.load_businesses()
rev_df = preproc.load_reviews()

print(f"Loaded {len(bus_df)} businesses and {len(rev_df)} review interactions.")

# %%
bus_df[['name', 'city', 'state', 'stars', 'review_count', 'price_range']].head(10)

# %%
print("Rating Distribution:")
print(bus_df['stars'].value_counts().sort_index())
